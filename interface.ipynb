# %% [markdown]
# This interface is implemented in python and presents the following analyses: <br>
# 1 Participants Stats <br>
# 2 BoxPlot Graph by Time <br>
# 3 BoxPlot Graph by Grade <br>
# 4 WordCloud for Positive Feelings <br>
# 5 WordCloud for Negative Feelings <br>
# 6 General Experience <br>
# 7 Specific Experience vs Task Time <br>
# Note: Each function is displayed individually, with a message shown immediately after the graph or the results of a block.

# %%
from server.experience import experience
experience()

# %% [markdown]
# The graph illustrates the participants' experience in the industry. None of the participants had more than three years of experience, with most falling into the no-experience category.

# %%
from server.quant import boxplotLLM
boxplotLLM('Time')

# %%
from server.quant import boxplotLLM
boxplotLLM('Grade')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 2
#       1 from server.quant import boxplotLLM
# ----> 2 boxplotLLM('Grade')
#
# File c:\Users\user\Desktop\Repositórios\Sbes-2025-LLMReq\server\quant.py:14, in boxplotLLM(column)
#      12 df['llm'] = df['llm'].replace({ 'Com o uso de LLM': 'YES', 'Sem o uso de LLM': 'NO' })
#      13 plt.figure(figsize=(8, 6))
# ---> 14 df.boxplot(column, by='llm')
#      15 plt.title("LLM Usage vs " + column)
#      16 plt.suptitle("")  # Remove o título automático de "Boxplot grouped by"
#
# File c:\Users\user\Desktop\Repositórios\Sbes-2025-LLMReq\env\Lib\site-packages\pandas\plotting\_core.py:533, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     516 @Substitution(data="", backend=_backend_doc)
#     517 @Appender(_boxplot_doc)
#     518 def boxplot_frame(
#    (...)    530     **kwargs,
#     531 ):
#     532     plot_backend = _get_plot_backend(backend)
# --> 533     return plot_backend.boxplot_frame(
#     534         self,
#     535         column=column,
#     536         by=by,
#     537         ax=ax,
#     538         fontsize=fontsize,
#     539         rot=rot,
#     540         grid=grid,
#     541         figsize=figsize,
#     542         layout=layout,
#     543         return_type=return_type,
#     544         **kwargs,
#     545     )
#
# File c:\Users\user\Desktop\Repositórios\Sbes-2025-LLMReq\env\Lib\site-packages\pandas\plotting\_matplotlib\boxplot.py:492, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     477 def boxplot_frame(
#     478     self,
#     479     column=None,
#    (...)    488     **kwds,
#     489 ):
#     490     import matplotlib.pyplot as plt
# --> 492     ax = boxplot(
#     493         self,
#     494         column=column,
#     495         by=by,
#     496         ax=ax,
#     497         fontsize=fontsize,
#     498         grid=grid,
#     499         rot=rot,
#     500         figsize=figsize,
#     501         layout=layout,
#     502         return_type=return_type,
#     503         **kwds,
#     504     )
#     505     plt.draw_if_interactive()
#     506     return ax
#
# File c:\Users\user\Desktop\Repositórios\Sbes-2025-LLMReq\env\Lib\site-packages\pandas\plotting\_matplotlib\boxplot.py:438, in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     433     columns = [column]
#     435 if by is not None:
#     436     # Prefer array return type for 2-D plots to match the subplot layout
#     437     # https://github.com/pandas-dev/pandas/pull/12216#issuecomment-241175580
# --> 438     result = _grouped_plot_by_column(
#     439         plot_group,
#     440         data,
#     441         columns=columns,
#     442         by=by,
#     443         grid=grid,
#     444         figsize=figsize,
#     445         ax=ax,
#     446         layout=layout,
#     447         return_type=return_type,
#     448         **kwds,
#     449     )
#     450 else:
#     451     if return_type is None:
#
# File c:\Users\user\Desktop\Repositórios\Sbes-2025-LLMReq\env\Lib\site-packages\pandas\plotting\_matplotlib\boxplot.py:327, in _grouped_plot_by_column(plotf, data, columns, by, numeric_only, grid, figsize, ax, layout, return_type, **kwargs)
#     325 for i, col in enumerate(columns):
#     326     ax = _axes[i]
# --> 327     gp_col = grouped[col]
#     328     keys, values = zip(*gp_col)
#     329     re_plotf = plotf(keys, values, ax, xlabel=xlabel, ylabel=ylabel, **kwargs)
#
# File c:\Users\user\Desktop\Repositórios\Sbes-2025-LLMReq\env\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File c:\Users\user\Desktop\Repositórios\Sbes-2025-LLMReq\env\Lib\site-packages\pandas\core\base.py:244, in SelectionMixin.__getitem__(self, key)
#     242 else:
#     243     if key not in self.obj:
# --> 244         raise KeyError(f"Column not found: {key}")
#     245     ndim = self.obj[key].ndim
#     246     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: Grade'

# %%
from server.quali import positiveWordCloud, negativeWordCloud
positiveWordCloud()
negativeWordCloud()

# %%
from server.knowledge import knowledgeHeatMap
knowledgeHeatMap()

# knowledgeBoxplot ('Object-Oriented Programming') 
# knowledgeBoxplot ('Software Architecture')
# knowledgeBoxplot ('Database Systems')
# knowledgeBoxplot ('Software Project Management')
# knowledgeBoxplot ('Requirements Engineering or Software Analysis')
# knowledgeBoxplot ('Agile Software Development Methods')
# knowledgeBoxplot ('Use of LLMs in Software Development')

# %%
from server.experience import experienceByTime
experienceByTime()
